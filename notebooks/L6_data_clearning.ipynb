# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/stefmolin/pandas-workshop/main?urlpath=lab/tree/notebooks/2-data_wrangling.ipynb) [![View slides in browser](https://img.shields.io/badge/view-slides-orange?logo=reveal.js&logoColor=white)](https://stefaniemolin.com/pandas-workshop/#/section-2)
#
# ---

# %% [markdown]
# # Lecture 6: Data Cleaning and Preprocessing
#
# To prepare our data for analysis, we need to perform data wrangling. In this section, we will learn how to clean and reformat data (e.g., renaming columns and fixing data type mismatches), restructure/reshape it, and enrich it (e.g., discretizing columns, calculating aggregations, and combining data sources).

# %% [markdown]
# ## Data cleaning with Pandas
#
# In this section, we will take a look at creating, renaming, and dropping columns; type conversion; and sorting &ndash; all of which make our analysis easier. We will be working with the Messy HR data.

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('../Messy-dataset/messy_HR_data.csv')

df.head()
# Out:
#        Name  Age          Salary  Gender Department  Position   Joining Date  \
# 0    grace    25           50000    Male         HR   Manager  April 5, 2018
# 1    david   NaN           65000  Female    Finance  Director     2020/02/20
# 2   hannah    35  SIXTY THOUSAND  Female      Sales  Director     01/15/2020
# 3      eve   NaN           50000  Female         IT   Manager  April 5, 2018
# 4    grace   NaN            NAN   Female    Finance   Manager     01/15/2020
#
#   Performance Score              Email  Phone Number
# 0                 D  email@example.com           NaN
# 1                 F    user@domain.com  123-456-7890
# 2                 C  email@example.com  098-765-4321
# 3                 A   name@company.org
# 4                 F   name@company.org  098-765-4321

# %% [markdown]
# *Source: [Messy-dataset](https://github.com/eyowhite/Messy-dataset).*

# %% [markdown]
# ### 1. Inspect the Data

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1000 non-null   object
#  1   Age                841 non-null    object
#  2   Salary             1000 non-null   object
#  3   Gender             1000 non-null   object
#  4   Department         1000 non-null   object
#  5   Position           1000 non-null   object
#  6   Joining Date       1000 non-null   object
#  7   Performance Score  1000 non-null   object
#  8   Email              610 non-null    object
#  9   Phone Number       815 non-null    object
# dtypes: object(10)
# memory usage: 78.3+ KB
#            Name     Age Salary Gender Department   Position Joining Date  \
# count      1000     841   1000   1000       1000       1000         1000
# unique       10       5      6      3          5          5            5
# top      alice   thirty  65000   Male    Finance  Assistant   2020/02/20
# freq        118     176    184    355        218        214          232
#
#        Performance Score            Email  Phone Number
# count               1000              610           815
# unique                 5                3             4
# top                    B  user@domain.com  123-456-7890
# freq                 225              213           236

# %% [markdown]
# What to look for:
# - Missing values
# - Wrong data types (dates as strings, numbers as objects)
# - Unexpected zeros or negatives
# - Outliers

# %% [markdown]
# ### 2. Fixed data types

# %%
df = df.copy()

df = df.applymap(
    lambda x: x.strip() if isinstance(x, str) else x
)

df.replace(
    ['N/A', 'NA', 'na', 'None', '', '?', 'unknown'],
    pd.NA,
    inplace=True
)

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce').astype('Int64')

# %%
df['Salary'] = (
    df['Salary']
    .str.replace(r'[\$,]', '', regex=True)
)

df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

# %%
df['Joining Date'] = pd.to_datetime(
    df['Joining Date'],
    errors='coerce'
)

# %%
categorical_cols = [
    'Gender',
    'Department',
    'Position',
    'Performance Score'
]

df[categorical_cols] = df[categorical_cols].astype('category')

# %%
string_cols = [
    'Name',
    'Email',
    'Phone Number'
]

df[string_cols] = df[string_cols].astype('string')

# %%
df.loc[~df['Email'].str.contains('@', na=False), 'Email'] = pd.NA
df['Phone Number'] = df['Phone Number'].str.replace(r'\D', '', regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1000 non-null   string
#  1   Age                665 non-null    Int64
#  2   Salary             690 non-null    float64
#  3   Gender             1000 non-null   category
#  4   Department         1000 non-null   category
#  5   Position           1000 non-null   category
#  6   Joining Date       186 non-null    datetime64[ns]
#  7   Performance Score  1000 non-null   category
#  8   Email              610 non-null    string
#  9   Phone Number       624 non-null    string
# dtypes: Int64(1), category(4), datetime64[ns](1), float64(1), string(3)
# memory usage: 52.6 KB

# %% [markdown]
# ### 3. Handle Missing Values

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Joining Date         814
# Email                390
# Phone Number         376
# Age                  335
# Salary               310
# Name                   0
# Gender                 0
# Department             0
# Position               0
# Performance Score      0
# dtype: int64

# %%
df = df.dropna(subset=['Name'])
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
df['Gender'] = df['Gender'].fillna(
    df['Gender'].mode()[0]
)
df['Department'] = df['Department'].fillna(
    df['Department'].mode()[0]
)
df['Position'] = df['Position'].fillna(
    df['Position'].mode()[0]
)

# Keep the same as original
df['Performance Score'] = df['Performance Score']
df['Joining Date'] = df['Joining Date']
df[['Email', 'Phone Number']] = df[['Email', 'Phone Number']]

df.isna().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1000 non-null   string
#  1   Age                1000 non-null   Int64
#  2   Salary             1000 non-null   float64
#  3   Gender             1000 non-null   category
#  4   Department         1000 non-null   category
#  5   Position           1000 non-null   category
#  6   Joining Date       186 non-null    datetime64[ns]
#  7   Performance Score  1000 non-null   category
#  8   Email              610 non-null    string
#  9   Phone Number       624 non-null    string
# dtypes: Int64(1), category(4), datetime64[ns](1), float64(1), string(3)
# memory usage: 52.6 KB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Joining Date         814
# Email                390
# Phone Number         376
# Name                   0
# Age                    0
# Salary                 0
# Gender                 0
# Department             0
# Position               0
# Performance Score      0
# dtype: int64

# %% [markdown]
# ### 4. Remove Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 5. Validate Data Ranges & Logic

# %%
df = df[(df['Age'] >= 16) & (df['Age'] <= 75)]
df = df[df['Salary'] > 0]

# %% [markdown]
# ### 6. Detect & Handle Outliers

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

df = df[
    (df['Salary'] >= Q1 - 1.5 * IQR) &
    (df['Salary'] <= Q3 + 1.5 * IQR)
]

# %% [markdown]
# ### 7. Standardize Text Data

# %%
text_cols = ['Gender', 'Department', 'Position']

df[text_cols] = (
    df[text_cols]
    .apply(lambda col: col.str.lower().str.strip())
)

# %% [markdown]
# ## Data cleaning with PandasAI using LLMs

# %%
# safe for JSON serialization.
# df = df.copy()
# df = df.applymap(
#     lambda x: x.strip() if isinstance(x, str) else x
# )
# df.replace(
#     ['N/A', 'NA', 'na', 'None', '', '?', 'unknown'],
#     pd.NA,
#     inplace=True
# )
# df['Age'] = pd.to_numeric(df['Age'], errors='coerce').astype('Int64')
# df['Salary'] = (
#     df['Salary']
#     .str.replace(r'[\$,]', '', regex=True)
# )

# df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')
# df['Joining Date'] = pd.to_datetime(
#     df['Joining Date'],
#     errors='coerce'
# )
# categorical_cols = [
#     'Gender',
#     'Department',
#     'Position',
#     'Performance Score'
# ]

# df[categorical_cols] = df[categorical_cols].astype('category')

# # Convert categories to strings
# cat_cols = df.select_dtypes(['category']).columns
# df[cat_cols] = df[cat_cols].astype(str)
# # Convert datetime to ISO format strings
# date_cols = df.select_dtypes(['datetime64[ns]']).columns
# df[date_cols] = df[date_cols].astype(str)

# string_cols = [
#     'Name',
#     'Email',
#     'Phone Number'
# ]

# df[string_cols] = df[string_cols].astype('string')

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Setup PandasAI with a LLM

# %%
import os
import pandas as pd
from pandasai import SmartDataframe
from pandasai.llm.openai import OpenAI

# Set your OpenAI API key
# os.environ["OPENAI_API_KEY"] = "sk-your_api_key_here"  # replace with your key

# Load your HR dataset
# df = pd.read_csv("../Messy-dataset/messy_HR_data.csv")
df = pd.read_csv("../Messy-dataset/cleaned_messy_HR_data.csv")

# Initialize LLM and SmartDataframe
openai_api_key = os.environ["OPENAI_API_KEY"]
llm = OpenAI(api_token=openai_api_key)
sdf = SmartDataframe(df.sample(50), config={"llm": llm})

# %% [markdown]
# ### 2. Prompt:
# #### 2.1 Summary & Missing Data

# %%
import sys
sys.setrecursionlimit(5000)
# Ask AI to summarize the dataset
summary = sdf.chat("Summarize this HR dataset: column types, missing values, and basic stats") # 
print(summary)
# Out:
#                         column_types  missing_values  \
# Name                          string               0
# Age                            Int64               0
# Salary                       float64               0
# Gender                        object               0
# Department                    object               0
# Position                      object               0
# Joining Date          datetime64[ns]               0
# Performance Score            float64              50
# Email                         string              22
# Phone Number                  string              21
# Tenure                         int64               0
# Salary_Band                 category               0
# Performance_Category        category              50
#
#                                                             basic_stats
# Name                  {'count': 50, 'unique': 9, 'top': 'alice', 'fr...
# Age                   {'count': 50.0, 'unique': <NA>, 'top': <NA>, '...
# Salary                {'count': 50.0, 'unique': nan, 'top': nan, 'fr...
# Gender                {'count': 50, 'unique': 3, 'top': 'Female', 'f...
# Department            {'count': 50, 'unique': 5, 'top': 'Marketing',...
# Position              {'count': 50, 'unique': 5, 'top': 'Manager', '...
# Joining Date          {'count': 50, 'unique': 5, 'top': 2020-01-15 0...
# Performance Score     {'count': 0.0, 'unique': nan, 'top': nan, 'fre...
# Email                 {'count': 28, 'unique': 3, 'top': 'user@domain...
# Phone Number          {'count': 29, 'unique': 3, 'top': '123-456-789...
# Tenure                {'count': 50.0, 'unique': nan, 'top': nan, 'fr...
# Salary_Band           {'count': 50, 'unique': 3, 'top': 'Low', 'freq...
# Performance_Category  {'count': 0, 'unique': 0, 'top': nan, 'freq': ...
# Unfortunately, I was not able to answer your question, because of the following error:
#
# Maximum recursion level reached
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#       ^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandasai/pipelines/chat/code_execution.py", line 133, in execute
#     {"content_type": "response", "value": ResponseSerializer.serialize(result)},
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandasai/responses/response_serializer.py", line 27, in serialize
#     df_dict = ResponseSerializer.serialize_dataframe(result["value"])
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandasai/responses/response_serializer.py", line 11, in serialize_dataframe
#     json_data = json.loads(df.to_json(orient="split", date_format="iso"))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py", line 2650, in to_json
#     return json.to_json(
#            ^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/io/json/_json.py", line 171, in to_json
#     ).write()
#       ^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pandas/io/json/_json.py", line 224, in write
#     return dumps(
#            ^^^^^^
# OverflowError: Maximum recursion level reached

# %% [markdown]
# #### 2.2 Detect Outliers

# %%
outliers = sdf.chat("Detect outliers in Age, Salary, and Performance Score columns and suggest handling")
print(outliers)
# Out:
# Age Outliers:
#         Name  Age   Salary  Gender Department   Position Joining Date  \
# 10     david   25  70000.0    Male  Marketing    Analyst   2019-12-01
# 417     jack   50  50000.0    Male         IT    Analyst   2018-04-05
# 793  charlie   50  70000.0  Female    Finance    Manager   2019-03-25
# 181      eve   50  70000.0   Other  Marketing      Clerk   2018-04-05
# 704      bob   25  70000.0  Female  Marketing  Assistant   2019-12-01
# 635   hannah   25  55000.0    Male         HR   Director   2018-04-05
# 743  charlie   25  70000.0  Female         IT    Manager   2019-03-25
# 122  charlie   25  65000.0  Female      Sales    Manager   2020-01-15
# 235      eve   25  65000.0   Other         HR    Manager   2018-04-05
# 831    alice   50  65000.0    Male         IT    Manager   2019-12-01
# 502    alice   25  50000.0  Female      Sales    Analyst   2020-01-15
# 883   hannah   50  65000.0  Female  Marketing  Assistant   2020-02-20
# 647      ivy   25  70000.0   Other    Finance  Assistant   2020-01-15
# 193    alice   25  65000.0   Other    Finance    Analyst   2020-01-15
# 790     jack   25  65000.0    Male  Marketing   Director   2020-02-20
# 383     jack   50  65000.0   Other  Marketing    Analyst   2019-12-01
#
#      Performance Score              Email  Phone Number  Tenure Salary_Band  \
# 10                 NaN               <NA>  123-456-7890      74   Very High
# 417                NaN               <NA>          <NA>      94         Low
# 793                NaN    user@domain.com          <NA>      82   Very High
# 181                NaN   name@company.org          <NA>      94   Very High
# 704                NaN               <NA>          <NA>      74   Very High
# 635                NaN               <NA>  555-555-5555      94         Low
# 743                NaN               <NA>          <NA>      82   Very High
# 122                NaN               <NA>  123-456-7890      72      Medium
# 235                NaN               <NA>  555-555-5555      94      Medium
# 831                NaN   name@company.org          <NA>      74      Medium
# 502                NaN  email@example.com  098-765-4321      72         Low
# 883                NaN    user@domain.com  098-765-4321      71      Medium
# 647                NaN   name@company.org  123-456-7890      72   Very High
# 193                NaN    user@domain.com          <NA>      72      Medium
# 790                NaN               <NA>  555-555-5555      71      Medium
# 383                NaN    user@domain.com          <NA>      74      Medium
#
#     Performance_Category
# 10                   NaN
# 417                  NaN
# 793                  NaN
# 181                  NaN
# 704                  NaN
# 635                  NaN
# 743                  NaN
# 122                  NaN
# 235                  NaN
# 831                  NaN
# 502                  NaN
# 883                  NaN
# 647                  NaN
# 193                  NaN
# 790                  NaN
# 383                  NaN
# Handling Suggestion: Consider capping at 16 and 75 or replacing with median.
#
# Salary Outliers:
# Empty DataFrame
# Columns: [Name, Age, Salary, Gender, Department, Position, Joining Date, Performance Score, Email, Phone Number, Tenure, Salary_Band, Performance_Category]
# Index: []
# Handling Suggestion: Consider capping at a reasonable maximum or replacing with median.
#
# Performance Score Outliers:
# Empty DataFrame
# Columns: [Name, Age, Salary, Gender, Department, Position, Joining Date, Performance Score, Email, Phone Number, Tenure, Salary_Band, Performance_Category]
# Index: []
# Handling Suggestion: Consider capping at a reasonable maximum or replacing with median.
#
# Outliers detected and suggestions provided for handling.

# %% [markdown]
# #### 2.3 Automated Cleaning Suggestions

# %%
cleaned_df = sdf.chat("""
Clean the dataset:
- Impute missing Age with median
- Impute missing Salary with median
- Fill missing Gender/Department/Position with mode
- Leave Email and Phone Number missing
- Remove duplicates
Return the cleaned DataFrame
""")

# %%
cleaned_df
# Out:
#         Name  Age   Salary  Gender Department   Position Joining Date  \
# 10     david   25  70000.0    Male  Marketing    Analyst   2019-12-01
# 576    alice   40  65000.0    Male    Finance      Clerk   2018-04-05
# 232      bob   40  65000.0  Female    Finance    Analyst   2020-01-15
# 611   hannah   40  55000.0   Other      Sales    Manager   2019-12-01
# 417     jack   50  50000.0    Male         IT    Analyst   2018-04-05
# 793  charlie   50  70000.0  Female    Finance    Manager   2019-03-25
# 965    david   35  65000.0  Female  Marketing   Director   2018-04-05
# 181      eve   50  70000.0   Other  Marketing      Clerk   2018-04-05
# 783     jack   40  50000.0    Male         IT  Assistant   2018-04-05
# 704      bob   25  70000.0  Female  Marketing  Assistant   2019-12-01
# 236    grace   40  55000.0    Male      Sales      Clerk   2020-01-15
# 294    alice   40  50000.0   Other  Marketing    Manager   2019-12-01
# 635   hannah   25  55000.0    Male         HR   Director   2018-04-05
# 386      eve   40  65000.0    Male         IT    Manager   2019-03-25
# 640    alice   40  65000.0    Male         HR   Director   2019-03-25
# 24       ivy   40  50000.0   Other    Finance    Manager   2018-04-05
# 967      bob   40  70000.0    Male         HR  Assistant   2018-04-05
# 743  charlie   25  70000.0  Female         IT    Manager   2019-03-25
# 118    grace   35  70000.0   Other  Marketing   Director   2019-12-01
# 293  charlie   35  55000.0    Male  Marketing   Director   2020-02-20
# 122  charlie   25  65000.0  Female      Sales    Manager   2020-01-15
# 751      bob   40  55000.0    Male    Finance    Analyst   2020-01-15
# 235      eve   25  65000.0   Other         HR    Manager   2018-04-05
# 850      bob   40  65000.0   Other         IT  Assistant   2019-03-25
# 831    alice   50  65000.0    Male         IT    Manager   2019-12-01
# 124    alice   40  55000.0  Female  Marketing      Clerk   2020-01-15
# 911   hannah   40  50000.0    Male    Finance    Manager   2018-04-05
# 807      ivy   40  70000.0  Female      Sales      Clerk   2018-04-05
# 449  charlie   35  65000.0  Female      Sales      Clerk   2020-02-20
# 699  charlie   40  65000.0   Other         IT  Assistant   2020-01-15
# 502    alice   25  50000.0  Female      Sales    Analyst   2020-01-15
# 260      bob   40  65000.0    Male      Sales   Director   2020-01-15
# 883   hannah   50  65000.0  Female  Marketing  Assistant   2020-02-20
# 852    david   40  55000.0  Female         HR    Analyst   2020-01-15
# 647      ivy   25  70000.0   Other    Finance  Assistant   2020-01-15
# 705      bob   40  65000.0   Other         HR      Clerk   2020-02-20
# 988    david   40  70000.0  Female         IT    Manager   2019-12-01
# 99    hannah   40  70000.0    Male         HR    Manager   2020-02-20
# 630  charlie   40  55000.0  Female      Sales  Assistant   2020-01-15
# 193    alice   25  65000.0   Other    Finance    Analyst   2020-01-15
# 391      eve   40  55000.0  Female    Finance      Clerk   2020-02-20
# 724    alice   40  65000.0   Other      Sales  Assistant   2018-04-05
# 450      eve   40  55000.0   Other         IT    Analyst   2020-01-15
# 790     jack   25  65000.0    Male  Marketing   Director   2020-02-20
# 866     jack   40  55000.0  Female         HR      Clerk   2019-12-01
# 714    grace   40  50000.0  Female  Marketing   Director   2019-12-01
# 114    alice   40  70000.0   Other         IT   Director   2019-12-01
# 82    hannah   40  50000.0   Other    Finance    Manager   2020-02-20
# 383     jack   50  65000.0   Other  Marketing    Analyst   2019-12-01
# 96       ivy   40  70000.0   Other  Marketing    Analyst   2019-03-25
#
#     Performance Score              Email  Phone Number
# 10                  B               <NA>  123-456-7890
# 576                 F               <NA>          <NA>
# 232                 D  email@example.com  098-765-4321
# 611                 A  email@example.com  123-456-7890
# 417                 A               <NA>          <NA>
# 793                 B    user@domain.com          <NA>
# 965                 A  email@example.com  123-456-7890
# 181                 B   name@company.org          <NA>
# 783                 B               <NA>          <NA>
# 704                 C               <NA>          <NA>
# 236                 B               <NA>          <NA>
# 294                 B    user@domain.com  123-456-7890
# 635                 F               <NA>  555-555-5555
# 386                 A    user@domain.com          <NA>
# 640                 B               <NA>  098-765-4321
# 24                  A   name@company.org  123-456-7890
# 967                 A               <NA>          <NA>
# 743                 B               <NA>          <NA>
# 118                 D               <NA>          <NA>
# 293                 D    user@domain.com          <NA>
# 122                 A               <NA>  123-456-7890
# 751                 A               <NA>  098-765-4321
# 235                 D               <NA>  555-555-5555
# 850                 F               <NA>          <NA>
# 831                 A   name@company.org          <NA>
# 124                 C  email@example.com          <NA>
# 911                 C   name@company.org  123-456-7890
# 807                 D               <NA>          <NA>
# 449                 C  email@example.com          <NA>
# 699                 B    user@domain.com  123-456-7890
# 502                 B  email@example.com  098-765-4321
# 260                 B               <NA>  555-555-5555
# 883                 C    user@domain.com  098-765-4321
# 852                 A               <NA>  555-555-5555
# 647                 C   name@company.org  123-456-7890
# 705                 F               <NA>  123-456-7890
# 988                 C    user@domain.com          <NA>
# 99                  C  email@example.com  098-765-4321
# 630                 C   name@company.org  123-456-7890
# 193                 A    user@domain.com          <NA>
# 391                 A   name@company.org  123-456-7890
# 724                 F  email@example.com  098-765-4321
# 450                 D    user@domain.com  555-555-5555
# 790                 F               <NA>  555-555-5555
# 866                 C               <NA>  555-555-5555
# 714                 B               <NA>  123-456-7890
# 114                 D   name@company.org  555-555-5555
# 82                  D  email@example.com          <NA>
# 383                 B    user@domain.com          <NA>
# 96                  B    user@domain.com  123-456-7890

# %% [markdown]
# #### Exploratory Data Analysis (EDA)

# %%
eda_summary = sdf.chat("""
Perform EDA:
- Show average Salary by Department and Position
- Show distribution of Age and Salary
- Show performance scores by Gender
- Visualize Salary distribution by Department
""")
print(eda_summary)
# Out:
#    Department   Position        Salary
# 0     Finance    Analyst  61666.666667
# 1     Finance  Assistant  70000.000000
# 2     Finance      Clerk  60000.000000
# 3     Finance    Manager  55000.000000
# 4          HR    Analyst  55000.000000
# 5          HR  Assistant  70000.000000
# 6          HR      Clerk  60000.000000
# 7          HR   Director  60000.000000
# 8          HR    Manager  67500.000000
# 9          IT    Analyst  52500.000000
# 10         IT  Assistant  60000.000000
# 11         IT   Director  70000.000000
# 12         IT    Manager  67500.000000
# 13  Marketing    Analyst  68333.333333
# 14  Marketing  Assistant  67500.000000
# 15  Marketing      Clerk  62500.000000
# 16  Marketing   Director  61000.000000
# 17  Marketing    Manager  50000.000000
# 18      Sales    Analyst  50000.000000
# 19      Sales  Assistant  60000.000000
# 20      Sales      Clerk  63333.333333
# 21      Sales   Director  65000.000000
# 22      Sales    Manager  60000.000000

# %% [markdown]
# Text summary (tables, means, medians)
# Generates plots inline (histograms, boxplots, bar charts)

# %% [markdown]
# #### Feature Engineering

# %%
features = sdf.chat("""
Suggest new features for predicting Performance Score:
- Derive Tenure from Joining Date
- Create Salary_Band based on quartiles
- Suggest any other useful columns
""")
print(features)
# Out:
#         Name  Age   Salary  Gender Department   Position Joining Date  \
# 10     david   25  70000.0    Male  Marketing    Analyst   2019-12-01
# 576    alice   40  65000.0    Male    Finance      Clerk   2018-04-05
# 232      bob   40  65000.0  Female    Finance    Analyst   2020-01-15
# 611   hannah   40  55000.0   Other      Sales    Manager   2019-12-01
# 417     jack   50  50000.0    Male         IT    Analyst   2018-04-05
# 793  charlie   50  70000.0  Female    Finance    Manager   2019-03-25
# 965    david   35  65000.0  Female  Marketing   Director   2018-04-05
# 181      eve   50  70000.0   Other  Marketing      Clerk   2018-04-05
# 783     jack   40  50000.0    Male         IT  Assistant   2018-04-05
# 704      bob   25  70000.0  Female  Marketing  Assistant   2019-12-01
# 236    grace   40  55000.0    Male      Sales      Clerk   2020-01-15
# 294    alice   40  50000.0   Other  Marketing    Manager   2019-12-01
# 635   hannah   25  55000.0    Male         HR   Director   2018-04-05
# 386      eve   40  65000.0    Male         IT    Manager   2019-03-25
# 640    alice   40  65000.0    Male         HR   Director   2019-03-25
# 24       ivy   40  50000.0   Other    Finance    Manager   2018-04-05
# 967      bob   40  70000.0    Male         HR  Assistant   2018-04-05
# 743  charlie   25  70000.0  Female         IT    Manager   2019-03-25
# 118    grace   35  70000.0   Other  Marketing   Director   2019-12-01
# 293  charlie   35  55000.0    Male  Marketing   Director   2020-02-20
# 122  charlie   25  65000.0  Female      Sales    Manager   2020-01-15
# 751      bob   40  55000.0    Male    Finance    Analyst   2020-01-15
# 235      eve   25  65000.0   Other         HR    Manager   2018-04-05
# 850      bob   40  65000.0   Other         IT  Assistant   2019-03-25
# 831    alice   50  65000.0    Male         IT    Manager   2019-12-01
# 124    alice   40  55000.0  Female  Marketing      Clerk   2020-01-15
# 911   hannah   40  50000.0    Male    Finance    Manager   2018-04-05
# 807      ivy   40  70000.0  Female      Sales      Clerk   2018-04-05
# 449  charlie   35  65000.0  Female      Sales      Clerk   2020-02-20
# 699  charlie   40  65000.0   Other         IT  Assistant   2020-01-15
# 502    alice   25  50000.0  Female      Sales    Analyst   2020-01-15
# 260      bob   40  65000.0    Male      Sales   Director   2020-01-15
# 883   hannah   50  65000.0  Female  Marketing  Assistant   2020-02-20
# 852    david   40  55000.0  Female         HR    Analyst   2020-01-15
# 647      ivy   25  70000.0   Other    Finance  Assistant   2020-01-15
# 705      bob   40  65000.0   Other         HR      Clerk   2020-02-20
# 988    david   40  70000.0  Female         IT    Manager   2019-12-01
# 99    hannah   40  70000.0    Male         HR    Manager   2020-02-20
# 630  charlie   40  55000.0  Female      Sales  Assistant   2020-01-15
# 193    alice   25  65000.0   Other    Finance    Analyst   2020-01-15
# 391      eve   40  55000.0  Female    Finance      Clerk   2020-02-20
# 724    alice   40  65000.0   Other      Sales  Assistant   2018-04-05
# 450      eve   40  55000.0   Other         IT    Analyst   2020-01-15
# 790     jack   25  65000.0    Male  Marketing   Director   2020-02-20
# 866     jack   40  55000.0  Female         HR      Clerk   2019-12-01
# 714    grace   40  50000.0  Female  Marketing   Director   2019-12-01
# 114    alice   40  70000.0   Other         IT   Director   2019-12-01
# 82    hannah   40  50000.0   Other    Finance    Manager   2020-02-20
# 383     jack   50  65000.0   Other  Marketing    Analyst   2019-12-01
# 96       ivy   40  70000.0   Other  Marketing    Analyst   2019-03-25
#
#      Performance Score              Email  Phone Number  Tenure Salary_Band  \
# 10                 NaN               <NA>  123-456-7890      74   Very High
# 576                NaN               <NA>          <NA>      94      Medium
# 232                NaN  email@example.com  098-765-4321      72      Medium
# 611                NaN  email@example.com  123-456-7890      74         Low
# 417                NaN               <NA>          <NA>      94         Low
# 793                NaN    user@domain.com          <NA>      82   Very High
# 965                NaN  email@example.com  123-456-7890      94      Medium
# 181                NaN   name@company.org          <NA>      94   Very High
# 783                NaN               <NA>          <NA>      94         Low
# 704                NaN               <NA>          <NA>      74   Very High
# 236                NaN               <NA>          <NA>      72         Low
# 294                NaN    user@domain.com  123-456-7890      74         Low
# 635                NaN               <NA>  555-555-5555      94         Low
# 386                NaN    user@domain.com          <NA>      82      Medium
# 640                NaN               <NA>  098-765-4321      82      Medium
# 24                 NaN   name@company.org  123-456-7890      94         Low
# 967                NaN               <NA>          <NA>      94   Very High
# 743                NaN               <NA>          <NA>      82   Very High
# 118                NaN               <NA>          <NA>      74   Very High
# 293                NaN    user@domain.com          <NA>      71         Low
# 122                NaN               <NA>  123-456-7890      72      Medium
# 751                NaN               <NA>  098-765-4321      72         Low
# 235                NaN               <NA>  555-555-5555      94      Medium
# 850                NaN               <NA>          <NA>      82      Medium
# 831                NaN   name@company.org          <NA>      74      Medium
# 124                NaN  email@example.com          <NA>      72         Low
# 911                NaN   name@company.org  123-456-7890      94         Low
# 807                NaN               <NA>          <NA>      94   Very High
# 449                NaN  email@example.com          <NA>      71      Medium
# 699                NaN    user@domain.com  123-456-7890      72      Medium
# 502                NaN  email@example.com  098-765-4321      72         Low
# 260                NaN               <NA>  555-555-5555      72      Medium
# 883                NaN    user@domain.com  098-765-4321      71      Medium
# 852                NaN               <NA>  555-555-5555      72         Low
# 647                NaN   name@company.org  123-456-7890      72   Very High
# 705                NaN               <NA>  123-456-7890      71      Medium
# 988                NaN    user@domain.com          <NA>      74   Very High
# 99                 NaN  email@example.com  098-765-4321      71   Very High
# 630                NaN   name@company.org  123-456-7890      72         Low
# 193                NaN    user@domain.com          <NA>      72      Medium
# 391                NaN   name@company.org  123-456-7890      71         Low
# 724                NaN  email@example.com  098-765-4321      94      Medium
# 450                NaN    user@domain.com  555-555-5555      72         Low
# 790                NaN               <NA>  555-555-5555      71      Medium
# 866                NaN               <NA>  555-555-5555      74         Low
# 714                NaN               <NA>  123-456-7890      74         Low
# 114                NaN   name@company.org  555-555-5555      74   Very High
# 82                 NaN  email@example.com          <NA>      71         Low
# 383                NaN    user@domain.com          <NA>      74      Medium
# 96                 NaN    user@domain.com  123-456-7890      82   Very High
#
#     Performance_Category Age_Group
# 10                   NaN     15-24
# 576                  NaN     35-44
# 232                  NaN     35-44
# 611                  NaN     35-44
# 417                  NaN     45-54
# 793                  NaN     45-54
# 965                  NaN     25-34
# 181                  NaN     45-54
# 783                  NaN     35-44
# 704                  NaN     15-24
# 236                  NaN     35-44
# 294                  NaN     35-44
# 635                  NaN     15-24
# 386                  NaN     35-44
# 640                  NaN     35-44
# 24                   NaN     35-44
# 967                  NaN     35-44
# 743                  NaN     15-24
# 118                  NaN     25-34
# 293                  NaN     25-34
# 122                  NaN     15-24
# 751                  NaN     35-44
# 235                  NaN     15-24
# 850                  NaN     35-44
# 831                  NaN     45-54
# 124                  NaN     35-44
# 911                  NaN     35-44
# 807                  NaN     35-44
# 449                  NaN     25-34
# 699                  NaN     35-44
# 502                  NaN     15-24
# 260                  NaN     35-44
# 883                  NaN     45-54
# 852                  NaN     35-44
# 647                  NaN     15-24
# 705                  NaN     35-44
# 988                  NaN     35-44
# 99                   NaN     35-44
# 630                  NaN     35-44
# 193                  NaN     15-24
# 391                  NaN     35-44
# 724                  NaN     35-44
# 450                  NaN     35-44
# 790                  NaN     15-24
# 866                  NaN     35-44
# 714                  NaN     35-44
# 114                  NaN     35-44
# 82                   NaN     35-44
# 383                  NaN     45-54
# 96                   NaN     35-44

# %% [markdown]
# #### Validation / QA

# %%
validation = sdf.chat("""
Check the dataset for any remaining issues:
- Missing values
- Duplicates
- Logical inconsistencies (Age < 16 or > 75, Salary < 0)
""")
print(validation)
# Out:
# {'type': 'string', 'value': 'Missing Values:\nName                     0\nAge                      0\nSalary                   0\nGender                   0\nDepartment               0\nPosition                 0\nJoining Date             0\nPerformance Score       50\nEmail                   22\nPhone Number            21\nTenure                   0\nSalary_Band              0\nPerformance_Category    50\nAge_Group                0\ndtype: int64\n\nDuplicates: 0\n\nAge Inconsistencies:\nEmpty DataFrame\nColumns: [Name, Age, Salary, Gender, Department, Position, Joining Date, Performance Score, Email, Phone Number, Tenure, Salary_Band, Performance_Category, Age_Group]\nIndex: []\n\nSalary Inconsistencies:\nEmpty DataFrame\nColumns: [Name, Age, Salary, Gender, Department, Position, Joining Date, Performance Score, Email, Phone Number, Tenure, Salary_Band, Performance_Category, Age_Group]\nIndex: []'}
# Missing Values:
# Name                     0
# Age                      0
# Salary                   0
# Gender                   0
# Department               0
# Position                 0
# Joining Date             0
# Performance Score       50
# Email                   22
# Phone Number            21
# Tenure                   0
# Salary_Band              0
# Performance_Category    50
# Age_Group                0
# dtype: int64
#
# Duplicates: 0
#
# Age Inconsistencies:
# Empty DataFrame
# Columns: [Name, Age, Salary, Gender, Department, Position, Joining Date, Performance Score, Email, Phone Number, Tenure, Salary_Band, Performance_Category, Age_Group]
# Index: []
#
# Salary Inconsistencies:
# Empty DataFrame
# Columns: [Name, Age, Salary, Gender, Department, Position, Joining Date, Performance Score, Email, Phone Number, Tenure, Salary_Band, Performance_Category, Age_Group]
# Index: []

# %% [markdown]
# AI highlights issues
#
# Suggests corrective actions if needed
